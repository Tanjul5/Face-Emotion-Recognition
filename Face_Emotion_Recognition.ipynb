# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanjul5/Face-Emotion-Recognition/blob/main/Face_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Live Class Monitoring System(Face Emotion Recognition)**

# %% [markdown]
# Emotion recognition is the process of identifying human emotion. People vary widely in their accuracy at recognizing the emotions of others. Use of technology to help people with emotion recognition is a relatively nascent research area. Generally, the technology works best if it uses multiple modalities in context. To date, the most work has been conducted on automating the recognition of facial expressions from video, spoken expressions from audio, written expressions from text, and physiology as measured by wearables.
#
# Facial expressions are a form of nonverbal communication. Various studies have been done for the classification of these facial expressions. There is strong evidence for the universal facial expressions of seven emotions which include: neutral happy, sadness, anger, disgust, fear, and surprise. So it is very important to detect these emotions on the face as it has wide applications in the field of Computer Vision and Artificial Intelligence. These fields are researching on the facial emotions to get the sentiments of the humans automatically.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Indian education landscape has been undergoing rapid changes for the past 10 years owing to the advancement of web-based learning services, specifically, eLearning platforms.
#
# Global E-learning is estimated to witness an 8X over the next 5 years to reach USD 2B in 2021. India is expected to grow with a CAGR of 44% crossing the 10M users mark in 2021. Although the market is growing on a rapid scale, there are major challenges associated with digital learning when compared with brick and mortar classrooms. One of many challenges is how to ensure quality learning for students. Digital platforms might overpower physical classrooms in terms of content quality but when it comes to understanding whether students are able to grasp the content in a live class scenario is yet an open-end challenge. In a physical classroom during a lecturing teacher can see the faces and assess the emotion of the class and tune their lecture accordingly, whether he is going fast or slow. He can identify students who need special attention.
#
# Digital classrooms are conducted via video telephony software program (ex-Zoom) where it’s not possible for medium scale class (25-50) to see all students and access the mood. Because of this drawback, students are not focusing on content due to lack of surveillance.
#
# While digital platforms have limitations in terms of physical surveillance but it comes with the power of data and machines which can work for you. It provides data in the form of video, audio, and texts which can be analyzed using deep learning algorithms.
#
# Deep learning backed system not only solves the surveillance issue, but it also removes the human bias from the system, and all information is no longer in the teacher’s brain rather translated in numbers that can be analyzed and tracked.
#
# I will solve the above-mentioned challenge by applying deep learning algorithms to live video data. The solution to this problem is by recognizing facial emotions.

# %% [markdown]
# I have built a deep learning model which detects the real time emotions of students through a webcam so that teachers can understand if students are able to grasp the topic according to students' expressions or emotions and then deploy the model. The model is trained on the FER-2013 dataset .This dataset consists of 35887 grayscale, 48x48 sized face images with seven emotions - angry, disgusted, fearful, happy, neutral, sad and surprised.

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 11.4 MB/s
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Installing collected packages: tf-estimator-nightly
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109

# %%
import os
import cv2
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

## CNN Models ##
import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import np_utils
from keras.regularizers import l2
from keras.datasets import mnist
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, SeparableConv2D
from keras.layers import Dropout, BatchNormalization, Activation
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras import models
from keras.utils.vis_utils import plot_model
from keras.layers import Input, GlobalAveragePooling2D,concatenate
from keras.models import Model
from keras import layers

tf.keras.applications.resnet50.ResNet50

#!pip keras.applications import ResNet50
from keras.models import load_model

from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# Reading CSV file
df = pd.read_csv('/content/drive/MyDrive/face emotion recognition/files/fer2013.csv')

# %%
df.head(2)
# Out:
#    emotion                                             pixels     Usage
# 0        0  70 80 82 72 58 58 60 63 54 58 60 48 89 115 121...  Training
# 1        0  151 150 147 155 148 133 111 140 170 174 182 15...  Training

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35887 entries, 0 to 35886
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   emotion  35887 non-null  int64
#  1   pixels   35887 non-null  object
#  2   Usage    35887 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 841.2+ KB

# %%
df[['Usage']].value_counts()
# Out:
# Usage
# Training       28709
# PrivateTest     3589
# PublicTest      3589
# dtype: int64

# %%
df[df['Usage']=='PrivateTest']
# Out:
#        emotion                                             pixels        Usage
# 32298        0  170 118 101 88 88 75 78 82 66 74 68 59 63 64 6...  PrivateTest
# 32299        5  7 5 8 6 7 3 2 6 5 4 4 5 7 5 5 5 6 7 7 7 10 10 ...  PrivateTest
# 32300        6  232 240 241 239 237 235 246 117 24 24 22 13 12...  PrivateTest
# 32301        4  200 197 149 139 156 89 111 58 62 95 113 117 11...  PrivateTest
# 32302        2  40 28 33 56 45 33 31 78 152 194 200 186 196 20...  PrivateTest
# ...        ...                                                ...          ...
# 35882        6  50 36 17 22 23 29 33 39 34 37 37 37 39 43 48 5...  PrivateTest
# 35883        3  178 174 172 173 181 188 191 194 196 199 200 20...  PrivateTest
# 35884        0  17 17 16 23 28 22 19 17 25 26 20 24 31 19 27 9...  PrivateTest
# 35885        3  30 28 28 29 31 30 42 68 79 81 77 67 67 71 63 6...  PrivateTest
# 35886        2  19 13 14 12 13 16 21 33 50 57 71 84 97 108 122...  PrivateTest
#
# [3589 rows x 3 columns]

# %%
df.shape
# Out:
# (35887, 3)

# %%
# Dictionary mapping for individual emotions
emotion_label_to_text = {0:'anger', 1:'disgust', 2:'fear', 3:'happiness', 4: 'sadness', 5: 'surprise', 6: 'neutral'}

# %%
# Plotting distribution of emotions
sns.countplot(df.emotion)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Read all Training images
fig = plt.figure(1, (14, 14))

k = 0
for label in sorted(df.emotion.unique()):
    for j in range(7):
        px = df[df.emotion==label].pixels.iloc[k]
        px = np.array(px.split(' ')).reshape(48, 48).astype('float32')

        k += 1
        ax = plt.subplot(7, 7, k)
        ax.imshow(px, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(emotion_label_to_text[label])
        plt.tight_layout()

# %%
df = df[df.emotion.isin(emotion_label_to_text)]
df.shape
# Out:
# (35887, 3)

# %%
batch_size = 32
num_epochs = 50
input_shape = (48, 48, 1)
validation_split = .2
verbose = 1
num_classes = 7
base_path = 'models/'
shape_x = 48
shape_y = 48
image_size=(48,48)

# %%
df['pixels']=df['pixels'].astype("string") #converting dtype of pixels to string
pixels = df['pixels'].tolist() #Making list of pixels
width, height = 48, 48 # initializing image shape
faces = [] #Empty list
# Making images as required for our models  
for pixel_sequence in pixels:
    face = [int(pixel) for pixel in pixel_sequence.strip().split(' ',48*48)]
    face = np.asarray(face).reshape(width, height)
    face = cv2.resize(face.astype('uint8'),image_size)
    faces.append(face.astype('float32'))
# Converting to array and dimension for transfer Learning
faces = np.asarray(faces)
faces = np.expand_dims(faces, -1)
faces /= 127.5 # normalizing the data
faces -= 1.
# Converting Emotions to numpy array
emotions = pd.get_dummies(df['emotion']).to_numpy()

# %% [markdown]
# Data Augmentation
#
# Data Augmentation:- taking the batch and apply some series of random transformations (random rotation, resizing, shearing) to increase generalizability of model.

# %%
# data generator Generate batches of tensor image data with real-time data augmentation
data_generator = ImageDataGenerator(
                        featurewise_center=False,#Set input mean to 0 over the dataset, feature-wise.
                        featurewise_std_normalization=False,# Divide inputs by std of the dataset, feature-wise.
                        rotation_range=10,      # randomly rotate images in the range (degrees, 0 to 180)
                        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
                        height_shift_range=0.1, # randomly shift images vertically (fraction of total height)
                        zoom_range=.1,          # randomly zoom into images
                        horizontal_flip=True)   # randomly flip images

# %% [markdown]
# ImageDataGenerator
#
# horizontal and vertical shift => moving all pixels of image in one direction
#
# width_shift_range ( horizonatal shift)
#
# height_shift_range (vertical shift)
#
# floating num [0- 1] --> % of shift
#
# horizontal n vertical flips augmentation ==>reversing rows or cols of pixels --> True or False
#
# Random rotation --> 0 - 360 degrees --> rotation_range = 90 ==> means random rotation to image blw 0 and 90 degrees
#
# random brightness --> randomly darkens or brightens images ==> brightness_range =[0.2,1.0] --> means darkens or brightens if pixel is blw 0.2 and 1
#
# random zoom
#
# either adds pixel or subtract pixels in image . [1-value, 1+value] for example , zoom_range = .3 --> range [0.7, 1.3] or blw 70%(zoom in) and 130% (zoomout)

# %% [markdown]
# Splitting data into train and test datset

# %%
from sklearn.model_selection import train_test_split
#train test split
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.3,shuffle=True)
xval,xtest,yval,ytest=train_test_split(xtest,ytest,test_size=0.3,shuffle=True)

# %%
# Checking shapes
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape, xval.shape, xtest.shape, yval.shape, ytest.shape
# Out:
# ((25120, 48, 48, 1),
#  (3231, 48, 48, 1),
#  (25120, 7),
#  (3231, 7),
#  (7536, 48, 48, 1),
#  (3231, 48, 48, 1),
#  (7536, 7),
#  (3231, 7))

# %% [markdown]
# # **Method 1: Xception **

# %%
# Defining entry flow
def entry_flow(inputs) :
    
    x = Conv2D(32, 3, strides = 2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(64,3,padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    previous_block_activation = x
    
    for size in [64, 128, 256] :
    
        x = Activation('relu')(x)
        x = SeparableConv2D(size, 3, padding='same')(x)
        x = BatchNormalization()(x)
    
        x = Activation('relu')(x)
        x = SeparableConv2D(size, 3, padding='same')(x)
        x = BatchNormalization()(x)
        
        x = MaxPooling2D(3, strides=2, padding='same')(x)
        
        residual = Conv2D(size, 1, strides=2, padding='same')(previous_block_activation)
        
        x = keras.layers.Add()([x, residual])
        previous_block_activation = x
    
    return x

# %%
# Defining middle flow
def middle_flow(x, num_blocks=8) :
    
    previous_block_activation = x
    
    for _ in range(num_blocks) :
    
        x = Activation('relu')(x)
        x = SeparableConv2D(256, 3, padding='same')(x)
        x = BatchNormalization()(x)
    
        x = Activation('relu')(x)
        x = SeparableConv2D(256, 3, padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Activation('relu')(x)
        x = SeparableConv2D(256, 3, padding='same')(x)
        x = BatchNormalization()(x)
        
        x = keras.layers.Add()([x, previous_block_activation])
        previous_block_activation = x
    
    return x

# %%
# Defining exit flow
def exit_flow(x, num_classes=7) :
    
    previous_block_activation = x
    
    x = Activation('relu')(x)
    x = SeparableConv2D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = Activation('relu')(x)
    x = SeparableConv2D(1024, 3, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = MaxPooling2D(3, strides=2, padding='same')(x)
    
    residual = Conv2D(1024, 1, strides=2, padding='same')(previous_block_activation)
    x = keras.layers.Add()([x, residual])
      
    x = Activation('relu')(x)
    x = SeparableConv2D(728, 3, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = Activation('relu')(x)
    x = SeparableConv2D(1024, 3, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)
    
    return x

# %%
# creating input and output of model
inputs = Input(shape=(shape_x, shape_y, 1))
outputs = exit_flow(middle_flow(entry_flow(inputs)))

# %%
# saving the model
xception = Model(inputs, outputs,name="Xception")

# %%
# Plotting architecture of defined model
plot_model(xception, to_file='xception.png', show_shapes=True, show_layer_names=True)

# %%
# Compiling the model
xception.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
xception.summary()  #gives the information about the architecture and configuration of the neural network.
# Out:
# Model: "Xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 24, 24, 32)   320         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 24, 24, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 24, 24, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   18496       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 24, 24, 64)   0           ['activation_1[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 24, 24, 64)  4736        ['activation_2[0][0]']
#  v2D)
#
#  batch_normalization_2 (BatchNo  (None, 24, 24, 64)  256         ['separable_conv2d[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_2[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 24, 24, 64)  4736        ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 24, 24, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 12, 12, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 12, 12, 64)   4160        ['activation_1[0][0]']
#
#  add (Add)                      (None, 12, 12, 64)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_4 (Activation)      (None, 12, 12, 64)   0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 12, 12, 128)  8896       ['activation_4[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 12, 12, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 12, 12, 128)  0           ['batch_normalization_4[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 12, 12, 128)  17664      ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 12, 12, 128)  512        ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 6, 6, 128)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 6, 6, 128)    8320        ['add[0][0]']
#
#  add_1 (Add)                    (None, 6, 6, 128)    0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  activation_6 (Activation)      (None, 6, 6, 128)    0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 6, 6, 256)   34176       ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 6, 6, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 6, 6, 256)    0           ['batch_normalization_6[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 6, 6, 256)   68096       ['activation_7[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 6, 6, 256)   1024        ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 3, 3, 256)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 3, 3, 256)    33024       ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 3, 3, 256)    0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  activation_8 (Activation)      (None, 3, 3, 256)    0           ['add_2[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 3, 3, 256)   68096       ['activation_8[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 3, 3, 256)   1024        ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 3, 3, 256)    0           ['batch_normalization_8[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 3, 3, 256)   68096       ['activation_9[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 3, 3, 256)   1024        ['separable_conv2d_7[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_9[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 3, 3, 256)   68096       ['activation_10[0][0]']
#  onv2D)
#
#  batch_normalization_10 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_10[0][0]',
#                                                                   'add_2[0][0]']
#
#  activation_11 (Activation)     (None, 3, 3, 256)    0           ['add_3[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 3, 3, 256)   68096       ['activation_11[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_9[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_11[0][0]']
#
#  separable_conv2d_10 (Separable  (None, 3, 3, 256)   68096       ['activation_12[0][0]']
#  Conv2D)
#
#  batch_normalization_12 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_10[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_12[0][0]']
#
#  separable_conv2d_11 (Separable  (None, 3, 3, 256)   68096       ['activation_13[0][0]']
#  Conv2D)
#
#  batch_normalization_13 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_13[0][0]',
#                                                                   'add_3[0][0]']
#
#  activation_14 (Activation)     (None, 3, 3, 256)    0           ['add_4[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 3, 3, 256)   68096       ['activation_14[0][0]']
#  Conv2D)
#
#  batch_normalization_14 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_14[0][0]']
#
#  separable_conv2d_13 (Separable  (None, 3, 3, 256)   68096       ['activation_15[0][0]']
#  Conv2D)
#
#  batch_normalization_15 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_15[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 3, 3, 256)   68096       ['activation_16[0][0]']
#  Conv2D)
#
#  batch_normalization_16 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_16[0][0]',
#                                                                   'add_4[0][0]']
#
#  activation_17 (Activation)     (None, 3, 3, 256)    0           ['add_5[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 3, 3, 256)   68096       ['activation_17[0][0]']
#  Conv2D)
#
#  batch_normalization_17 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_17[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 3, 3, 256)   68096       ['activation_18[0][0]']
#  Conv2D)
#
#  batch_normalization_18 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_17 (Separable  (None, 3, 3, 256)   68096       ['activation_19[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_17[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_19[0][0]',
#                                                                   'add_5[0][0]']
#
#  activation_20 (Activation)     (None, 3, 3, 256)    0           ['add_6[0][0]']
#
#  separable_conv2d_18 (Separable  (None, 3, 3, 256)   68096       ['activation_20[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_18[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_20[0][0]']
#
#  separable_conv2d_19 (Separable  (None, 3, 3, 256)   68096       ['activation_21[0][0]']
#  Conv2D)
#
#  batch_normalization_21 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_19[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_21[0][0]']
#
#  separable_conv2d_20 (Separable  (None, 3, 3, 256)   68096       ['activation_22[0][0]']
#  Conv2D)
#
#  batch_normalization_22 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_20[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_22[0][0]',
#                                                                   'add_6[0][0]']
#
#  activation_23 (Activation)     (None, 3, 3, 256)    0           ['add_7[0][0]']
#
#  separable_conv2d_21 (Separable  (None, 3, 3, 256)   68096       ['activation_23[0][0]']
#  Conv2D)
#
#  batch_normalization_23 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_21[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_23[0][0]']
#
#  separable_conv2d_22 (Separable  (None, 3, 3, 256)   68096       ['activation_24[0][0]']
#  Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_22[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_24[0][0]']
#
#  separable_conv2d_23 (Separable  (None, 3, 3, 256)   68096       ['activation_25[0][0]']
#  Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_23[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_25[0][0]',
#                                                                   'add_7[0][0]']
#
#  activation_26 (Activation)     (None, 3, 3, 256)    0           ['add_8[0][0]']
#
#  separable_conv2d_24 (Separable  (None, 3, 3, 256)   68096       ['activation_26[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_24[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_26[0][0]']
#
#  separable_conv2d_25 (Separable  (None, 3, 3, 256)   68096       ['activation_27[0][0]']
#  Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_25[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_27[0][0]']
#
#  separable_conv2d_26 (Separable  (None, 3, 3, 256)   68096       ['activation_28[0][0]']
#  Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_26[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_28[0][0]',
#                                                                   'add_8[0][0]']
#
#  activation_29 (Activation)     (None, 3, 3, 256)    0           ['add_9[0][0]']
#
#  separable_conv2d_27 (Separable  (None, 3, 3, 256)   68096       ['activation_29[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_27[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_29[0][0]']
#
#  separable_conv2d_28 (Separable  (None, 3, 3, 256)   68096       ['activation_30[0][0]']
#  Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_28[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_30[0][0]']
#
#  separable_conv2d_29 (Separable  (None, 3, 3, 256)   68096       ['activation_31[0][0]']
#  Conv2D)
#
#  batch_normalization_31 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_29[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 3, 3, 256)    0           ['batch_normalization_31[0][0]',
#                                                                   'add_9[0][0]']
#
#  activation_32 (Activation)     (None, 3, 3, 256)    0           ['add_10[0][0]']
#
#  separable_conv2d_30 (Separable  (None, 3, 3, 256)   68096       ['activation_32[0][0]']
#  Conv2D)
#
#  batch_normalization_32 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_30[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_32[0][0]']
#
#  separable_conv2d_31 (Separable  (None, 3, 3, 1024)  265472      ['activation_33[0][0]']
#  Conv2D)
#
#  batch_normalization_33 (BatchN  (None, 3, 3, 1024)  4096        ['separable_conv2d_31[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 1024)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 2, 2, 1024)   263168      ['add_10[0][0]']
#
#  add_11 (Add)                   (None, 2, 2, 1024)   0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  activation_34 (Activation)     (None, 2, 2, 1024)   0           ['add_11[0][0]']
#
#  separable_conv2d_32 (Separable  (None, 2, 2, 728)   755416      ['activation_34[0][0]']
#  Conv2D)
#
#  batch_normalization_34 (BatchN  (None, 2, 2, 728)   2912        ['separable_conv2d_32[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 2, 2, 728)    0           ['batch_normalization_34[0][0]']
#
#  separable_conv2d_33 (Separable  (None, 2, 2, 1024)  753048      ['activation_35[0][0]']
#  Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 2, 2, 1024)  4096        ['separable_conv2d_33[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['batch_normalization_35[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            7175        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 3,989,975
# Trainable params: 3,969,639
# Non-trainable params: 20,336
# __________________________________________________________________________________________________

# %%
# Compiling the model
xception.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
xception.summary()  #gives the information about the architecture and configuration of the neural network.
# Out:
# Model: "Xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 24, 24, 32)   320         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 24, 24, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 24, 24, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   18496       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 24, 24, 64)   0           ['activation_1[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 24, 24, 64)  4736        ['activation_2[0][0]']
#  v2D)
#
#  batch_normalization_2 (BatchNo  (None, 24, 24, 64)  256         ['separable_conv2d[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_2[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 24, 24, 64)  4736        ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 24, 24, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 12, 12, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 12, 12, 64)   4160        ['activation_1[0][0]']
#
#  add (Add)                      (None, 12, 12, 64)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_4 (Activation)      (None, 12, 12, 64)   0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 12, 12, 128)  8896       ['activation_4[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 12, 12, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 12, 12, 128)  0           ['batch_normalization_4[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 12, 12, 128)  17664      ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 12, 12, 128)  512        ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 6, 6, 128)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 6, 6, 128)    8320        ['add[0][0]']
#
#  add_1 (Add)                    (None, 6, 6, 128)    0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  activation_6 (Activation)      (None, 6, 6, 128)    0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 6, 6, 256)   34176       ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 6, 6, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 6, 6, 256)    0           ['batch_normalization_6[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 6, 6, 256)   68096       ['activation_7[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 6, 6, 256)   1024        ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 3, 3, 256)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 3, 3, 256)    33024       ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 3, 3, 256)    0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  activation_8 (Activation)      (None, 3, 3, 256)    0           ['add_2[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 3, 3, 256)   68096       ['activation_8[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 3, 3, 256)   1024        ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 3, 3, 256)    0           ['batch_normalization_8[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 3, 3, 256)   68096       ['activation_9[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 3, 3, 256)   1024        ['separable_conv2d_7[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_9[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 3, 3, 256)   68096       ['activation_10[0][0]']
#  onv2D)
#
#  batch_normalization_10 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_10[0][0]',
#                                                                   'add_2[0][0]']
#
#  activation_11 (Activation)     (None, 3, 3, 256)    0           ['add_3[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 3, 3, 256)   68096       ['activation_11[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_9[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_11[0][0]']
#
#  separable_conv2d_10 (Separable  (None, 3, 3, 256)   68096       ['activation_12[0][0]']
#  Conv2D)
#
#  batch_normalization_12 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_10[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_12[0][0]']
#
#  separable_conv2d_11 (Separable  (None, 3, 3, 256)   68096       ['activation_13[0][0]']
#  Conv2D)
#
#  batch_normalization_13 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_13[0][0]',
#                                                                   'add_3[0][0]']
#
#  activation_14 (Activation)     (None, 3, 3, 256)    0           ['add_4[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 3, 3, 256)   68096       ['activation_14[0][0]']
#  Conv2D)
#
#  batch_normalization_14 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_14[0][0]']
#
#  separable_conv2d_13 (Separable  (None, 3, 3, 256)   68096       ['activation_15[0][0]']
#  Conv2D)
#
#  batch_normalization_15 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_15[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 3, 3, 256)   68096       ['activation_16[0][0]']
#  Conv2D)
#
#  batch_normalization_16 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_16[0][0]',
#                                                                   'add_4[0][0]']
#
#  activation_17 (Activation)     (None, 3, 3, 256)    0           ['add_5[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 3, 3, 256)   68096       ['activation_17[0][0]']
#  Conv2D)
#
#  batch_normalization_17 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_17[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 3, 3, 256)   68096       ['activation_18[0][0]']
#  Conv2D)
#
#  batch_normalization_18 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_17 (Separable  (None, 3, 3, 256)   68096       ['activation_19[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_17[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_19[0][0]',
#                                                                   'add_5[0][0]']
#
#  activation_20 (Activation)     (None, 3, 3, 256)    0           ['add_6[0][0]']
#
#  separable_conv2d_18 (Separable  (None, 3, 3, 256)   68096       ['activation_20[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_18[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_20[0][0]']
#
#  separable_conv2d_19 (Separable  (None, 3, 3, 256)   68096       ['activation_21[0][0]']
#  Conv2D)
#
#  batch_normalization_21 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_19[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_21[0][0]']
#
#  separable_conv2d_20 (Separable  (None, 3, 3, 256)   68096       ['activation_22[0][0]']
#  Conv2D)
#
#  batch_normalization_22 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_20[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_22[0][0]',
#                                                                   'add_6[0][0]']
#
#  activation_23 (Activation)     (None, 3, 3, 256)    0           ['add_7[0][0]']
#
#  separable_conv2d_21 (Separable  (None, 3, 3, 256)   68096       ['activation_23[0][0]']
#  Conv2D)
#
#  batch_normalization_23 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_21[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_23[0][0]']
#
#  separable_conv2d_22 (Separable  (None, 3, 3, 256)   68096       ['activation_24[0][0]']
#  Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_22[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_24[0][0]']
#
#  separable_conv2d_23 (Separable  (None, 3, 3, 256)   68096       ['activation_25[0][0]']
#  Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_23[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_25[0][0]',
#                                                                   'add_7[0][0]']
#
#  activation_26 (Activation)     (None, 3, 3, 256)    0           ['add_8[0][0]']
#
#  separable_conv2d_24 (Separable  (None, 3, 3, 256)   68096       ['activation_26[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_24[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_26[0][0]']
#
#  separable_conv2d_25 (Separable  (None, 3, 3, 256)   68096       ['activation_27[0][0]']
#  Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_25[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_27[0][0]']
#
#  separable_conv2d_26 (Separable  (None, 3, 3, 256)   68096       ['activation_28[0][0]']
#  Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_26[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 3, 3, 256)    0           ['batch_normalization_28[0][0]',
#                                                                   'add_8[0][0]']
#
#  activation_29 (Activation)     (None, 3, 3, 256)    0           ['add_9[0][0]']
#
#  separable_conv2d_27 (Separable  (None, 3, 3, 256)   68096       ['activation_29[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_27[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_29[0][0]']
#
#  separable_conv2d_28 (Separable  (None, 3, 3, 256)   68096       ['activation_30[0][0]']
#  Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_28[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_30[0][0]']
#
#  separable_conv2d_29 (Separable  (None, 3, 3, 256)   68096       ['activation_31[0][0]']
#  Conv2D)
#
#  batch_normalization_31 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_29[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 3, 3, 256)    0           ['batch_normalization_31[0][0]',
#                                                                   'add_9[0][0]']
#
#  activation_32 (Activation)     (None, 3, 3, 256)    0           ['add_10[0][0]']
#
#  separable_conv2d_30 (Separable  (None, 3, 3, 256)   68096       ['activation_32[0][0]']
#  Conv2D)
#
#  batch_normalization_32 (BatchN  (None, 3, 3, 256)   1024        ['separable_conv2d_30[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_32[0][0]']
#
#  separable_conv2d_31 (Separable  (None, 3, 3, 1024)  265472      ['activation_33[0][0]']
#  Conv2D)
#
#  batch_normalization_33 (BatchN  (None, 3, 3, 1024)  4096        ['separable_conv2d_31[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 1024)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 2, 2, 1024)   263168      ['add_10[0][0]']
#
#  add_11 (Add)                   (None, 2, 2, 1024)   0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  activation_34 (Activation)     (None, 2, 2, 1024)   0           ['add_11[0][0]']
#
#  separable_conv2d_32 (Separable  (None, 2, 2, 728)   755416      ['activation_34[0][0]']
#  Conv2D)
#
#  batch_normalization_34 (BatchN  (None, 2, 2, 728)   2912        ['separable_conv2d_32[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 2, 2, 728)    0           ['batch_normalization_34[0][0]']
#
#  separable_conv2d_33 (Separable  (None, 2, 2, 1024)  753048      ['activation_35[0][0]']
#  Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 2, 2, 1024)  4096        ['separable_conv2d_33[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['batch_normalization_35[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            7175        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 3,989,975
# Trainable params: 3,969,639
# Non-trainable params: 20,336
# __________________________________________________________________________________________________

# %% [markdown]
# # **MODEL2**
#
# **CNN**

# %%
# Building up Model Architecture
def CNN():
    model = Sequential()

    #1st CNN layer
    model.add(Conv2D(64,(3,3),padding = 'same', name='image_array', input_shape = (48,48,1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.25))

    #2nd CNN layer
    model.add(Conv2D(128,(5,5),padding = 'same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout (0.25))

    #3rd CNN layer
    model.add(Conv2D(512,(3,3),padding = 'same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout (0.25))

    #4th CNN layer
    model.add(Conv2D(512,(3,3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())

    #Fully connected 1st layer
    model.add(Dense(256))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))


    # Fully connected layer 2nd layer
    model.add(Dense(512))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
CNN=CNN()

# %%
# Plotting architecture of defined model
plot_model(CNN, to_file='CNN.png', show_shapes=True, show_layer_names=True)

# %%
# Compiling the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001) #using Adam Optimizer
CNN.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
CNN.summary() #gives the information about the architecture and configuration of the neural network.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  image_array (Conv2D)        (None, 48, 48, 64)        640
#
#  batch_normalization_36 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  activation_36 (Activation)  (None, 48, 48, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_37 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  activation_37 (Activation)  (None, 24, 24, 128)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_38 (Bat  (None, 12, 12, 512)      2048
#  chNormalization)
#
#  activation_38 (Activation)  (None, 12, 12, 512)       0
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_8 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_39 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  activation_39 (Activation)  (None, 6, 6, 512)         0
#
#  max_pooling2d_7 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense_1 (Dense)             (None, 256)               1179904
#
#  batch_normalization_40 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_40 (Activation)  (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  batch_normalization_41 (Bat  (None, 512)              2048
#  chNormalization)
#
#  activation_41 (Activation)  (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________

# %% [markdown]
# # **Training**

# %% [markdown]
# # **Xception**

# %%
# Fitting the Model with Training and Validation Data
early_stop = EarlyStopping('val_loss', patience=50, min_delta=0, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1,
                                  patience=int(50/4), min_delta=0.0001,model='auto')
trained_models_path = base_path + '_Xception'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,
                                                    save_best_only=True)
callbacks = [model_checkpoint, early_stop, reduce_lr]

# %%
# Fitting the xception model
xception_history =xception.fit(data_generator.flow(xtrain, ytrain, batch_size),
          steps_per_epoch=len(xtrain) / batch_size, 
          epochs=num_epochs, 
          verbose=1, 
          callbacks=callbacks,
          validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 785/785 [==============================] - ETA: 0s - loss: 1.6580 - accuracy: 0.3445
# Epoch 1: val_loss improved from inf to 5.77996, saving model to models/_Xception.01-0.13.hdf5
# 785/785 [==============================] - 68s 66ms/step - loss: 1.6580 - accuracy: 0.3445 - val_loss: 5.7800 - val_accuracy: 0.1318 - lr: 0.0010
# Epoch 2/50
# 785/785 [==============================] - ETA: 0s - loss: 1.4544 - accuracy: 0.4365
# Epoch 2: val_loss improved from 5.77996 to 1.95590, saving model to models/_Xception.02-0.36.hdf5
# 785/785 [==============================] - 52s 66ms/step - loss: 1.4544 - accuracy: 0.4365 - val_loss: 1.9559 - val_accuracy: 0.3562 - lr: 0.0010
# Epoch 3/50
# 785/785 [==============================] - ETA: 0s - loss: 1.3567 - accuracy: 0.4762
# Epoch 3: val_loss improved from 1.95590 to 1.32466, saving model to models/_Xception.03-0.50.hdf5
# 785/785 [==============================] - 50s 64ms/step - loss: 1.3567 - accuracy: 0.4762 - val_loss: 1.3247 - val_accuracy: 0.5032 - lr: 0.0010
# Epoch 4/50
# 785/785 [==============================] - ETA: 0s - loss: 1.2997 - accuracy: 0.5089
# Epoch 4: val_loss did not improve from 1.32466
# 785/785 [==============================] - 50s 64ms/step - loss: 1.2997 - accuracy: 0.5089 - val_loss: 1.4813 - val_accuracy: 0.4401 - lr: 0.0010
# Epoch 5/50
# 785/785 [==============================] - ETA: 0s - loss: 1.2548 - accuracy: 0.5264
# Epoch 5: val_loss did not improve from 1.32466
# 785/785 [==============================] - 49s 62ms/step - loss: 1.2548 - accuracy: 0.5264 - val_loss: 1.3918 - val_accuracy: 0.4704 - lr: 0.0010
# Epoch 6/50
# 785/785 [==============================] - ETA: 0s - loss: 1.2158 - accuracy: 0.5390
# Epoch 6: val_loss did not improve from 1.32466
# 785/785 [==============================] - 49s 62ms/step - loss: 1.2158 - accuracy: 0.5390 - val_loss: 1.4195 - val_accuracy: 0.4822 - lr: 0.0010
# Epoch 7/50
# 785/785 [==============================] - ETA: 0s - loss: 1.1922 - accuracy: 0.5504
# Epoch 7: val_loss improved from 1.32466 to 1.28168, saving model to models/_Xception.07-0.50.hdf5
# 785/785 [==============================] - 51s 66ms/step - loss: 1.1922 - accuracy: 0.5504 - val_loss: 1.2817 - val_accuracy: 0.4974 - lr: 0.0010
# Epoch 8/50
# 785/785 [==============================] - ETA: 0s - loss: 1.1702 - accuracy: 0.5620
# Epoch 8: val_loss did not improve from 1.28168
# 785/785 [==============================] - 50s 63ms/step - loss: 1.1702 - accuracy: 0.5620 - val_loss: 1.4371 - val_accuracy: 0.5063 - lr: 0.0010
# Epoch 9/50
# 785/785 [==============================] - ETA: 0s - loss: 1.1465 - accuracy: 0.5671
# Epoch 9: val_loss did not improve from 1.28168
# 785/785 [==============================] - 49s 63ms/step - loss: 1.1465 - accuracy: 0.5671 - val_loss: 1.3929 - val_accuracy: 0.4875 - lr: 0.0010
# Epoch 10/50
# 785/785 [==============================] - ETA: 0s - loss: 1.1241 - accuracy: 0.5764
# Epoch 10: val_loss did not improve from 1.28168
# 785/785 [==============================] - 50s 63ms/step - loss: 1.1241 - accuracy: 0.5764 - val_loss: 1.5066 - val_accuracy: 0.4906 - lr: 0.0010
# Epoch 11/50
# 785/785 [==============================] - ETA: 0s - loss: 1.1136 - accuracy: 0.5811
# Epoch 11: val_loss did not improve from 1.28168
# 785/785 [==============================] - 49s 62ms/step - loss: 1.1136 - accuracy: 0.5811 - val_loss: 1.4549 - val_accuracy: 0.4673 - lr: 0.0010
# Epoch 12/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0944 - accuracy: 0.5888
# Epoch 12: val_loss did not improve from 1.28168
# 785/785 [==============================] - 50s 64ms/step - loss: 1.0944 - accuracy: 0.5888 - val_loss: 1.5856 - val_accuracy: 0.4348 - lr: 0.0010
# Epoch 13/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0811 - accuracy: 0.5906
# Epoch 13: val_loss improved from 1.28168 to 1.13107, saving model to models/_Xception.13-0.57.hdf5
# 785/785 [==============================] - 50s 63ms/step - loss: 1.0811 - accuracy: 0.5906 - val_loss: 1.1311 - val_accuracy: 0.5689 - lr: 0.0010
# Epoch 14/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0697 - accuracy: 0.6002
# Epoch 14: val_loss did not improve from 1.13107
# 785/785 [==============================] - 51s 65ms/step - loss: 1.0697 - accuracy: 0.6002 - val_loss: 1.3594 - val_accuracy: 0.5104 - lr: 0.0010
# Epoch 15/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0531 - accuracy: 0.6039
# Epoch 15: val_loss did not improve from 1.13107
# 785/785 [==============================] - 50s 63ms/step - loss: 1.0531 - accuracy: 0.6039 - val_loss: 1.2437 - val_accuracy: 0.5453 - lr: 0.0010
# Epoch 16/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0401 - accuracy: 0.6076
# Epoch 16: val_loss did not improve from 1.13107
# 785/785 [==============================] - 49s 63ms/step - loss: 1.0401 - accuracy: 0.6076 - val_loss: 1.1930 - val_accuracy: 0.5825 - lr: 0.0010
# Epoch 17/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0365 - accuracy: 0.6100
# Epoch 17: val_loss did not improve from 1.13107
# 785/785 [==============================] - 50s 64ms/step - loss: 1.0365 - accuracy: 0.6100 - val_loss: 1.1439 - val_accuracy: 0.5720 - lr: 0.0010
# Epoch 18/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0214 - accuracy: 0.6156
# Epoch 18: val_loss improved from 1.13107 to 1.08732, saving model to models/_Xception.18-0.60.hdf5
# 785/785 [==============================] - 52s 66ms/step - loss: 1.0214 - accuracy: 0.6156 - val_loss: 1.0873 - val_accuracy: 0.5970 - lr: 0.0010
# Epoch 19/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0101 - accuracy: 0.6244
# Epoch 19: val_loss did not improve from 1.08732
# 785/785 [==============================] - 49s 62ms/step - loss: 1.0101 - accuracy: 0.6244 - val_loss: 1.2641 - val_accuracy: 0.5602 - lr: 0.0010
# Epoch 20/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9986 - accuracy: 0.6258
# Epoch 20: val_loss improved from 1.08732 to 1.05358, saving model to models/_Xception.20-0.60.hdf5
# 785/785 [==============================] - 50s 63ms/step - loss: 0.9986 - accuracy: 0.6258 - val_loss: 1.0536 - val_accuracy: 0.5983 - lr: 0.0010
# Epoch 21/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9948 - accuracy: 0.6267
# Epoch 21: val_loss did not improve from 1.05358
# 785/785 [==============================] - 49s 62ms/step - loss: 0.9948 - accuracy: 0.6267 - val_loss: 1.1207 - val_accuracy: 0.5952 - lr: 0.0010
# Epoch 22/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9766 - accuracy: 0.6322
# Epoch 22: val_loss did not improve from 1.05358
# 785/785 [==============================] - 49s 62ms/step - loss: 0.9766 - accuracy: 0.6322 - val_loss: 1.0613 - val_accuracy: 0.6094 - lr: 0.0010
# Epoch 23/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9692 - accuracy: 0.6369
# Epoch 23: val_loss did not improve from 1.05358
# 785/785 [==============================] - 49s 63ms/step - loss: 0.9692 - accuracy: 0.6369 - val_loss: 1.1054 - val_accuracy: 0.5899 - lr: 0.0010
# Epoch 24/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9611 - accuracy: 0.6373
# Epoch 24: val_loss did not improve from 1.05358
# 785/785 [==============================] - 49s 63ms/step - loss: 0.9611 - accuracy: 0.6373 - val_loss: 1.1152 - val_accuracy: 0.6072 - lr: 0.0010
# Epoch 25/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9519 - accuracy: 0.6423
# Epoch 25: val_loss improved from 1.05358 to 1.03306, saving model to models/_Xception.25-0.62.hdf5
# 785/785 [==============================] - 50s 63ms/step - loss: 0.9519 - accuracy: 0.6423 - val_loss: 1.0331 - val_accuracy: 0.6246 - lr: 0.0010
# Epoch 26/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9412 - accuracy: 0.6507
# Epoch 26: val_loss did not improve from 1.03306
# 785/785 [==============================] - 49s 62ms/step - loss: 0.9412 - accuracy: 0.6507 - val_loss: 1.4333 - val_accuracy: 0.5388 - lr: 0.0010
# Epoch 27/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9328 - accuracy: 0.6490
# Epoch 27: val_loss improved from 1.03306 to 1.01826, saving model to models/_Xception.27-0.63.hdf5
# 785/785 [==============================] - 50s 64ms/step - loss: 0.9328 - accuracy: 0.6490 - val_loss: 1.0183 - val_accuracy: 0.6292 - lr: 0.0010
# Epoch 28/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9279 - accuracy: 0.6512
# Epoch 28: val_loss improved from 1.01826 to 1.01510, saving model to models/_Xception.28-0.62.hdf5
# 785/785 [==============================] - 50s 64ms/step - loss: 0.9279 - accuracy: 0.6512 - val_loss: 1.0151 - val_accuracy: 0.6218 - lr: 0.0010
# Epoch 29/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9167 - accuracy: 0.6562
# Epoch 29: val_loss improved from 1.01510 to 1.01443, saving model to models/_Xception.29-0.62.hdf5
# 785/785 [==============================] - 50s 64ms/step - loss: 0.9167 - accuracy: 0.6562 - val_loss: 1.0144 - val_accuracy: 0.6193 - lr: 0.0010
# Epoch 30/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9136 - accuracy: 0.6615
# Epoch 30: val_loss did not improve from 1.01443
# 785/785 [==============================] - 50s 64ms/step - loss: 0.9136 - accuracy: 0.6615 - val_loss: 1.0996 - val_accuracy: 0.5958 - lr: 0.0010
# Epoch 31/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9061 - accuracy: 0.6606
# Epoch 31: val_loss improved from 1.01443 to 0.97705, saving model to models/_Xception.31-0.64.hdf5
# 785/785 [==============================] - 51s 64ms/step - loss: 0.9061 - accuracy: 0.6606 - val_loss: 0.9770 - val_accuracy: 0.6441 - lr: 0.0010
# Epoch 32/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8988 - accuracy: 0.6645
# Epoch 32: val_loss did not improve from 0.97705
# 785/785 [==============================] - 49s 63ms/step - loss: 0.8988 - accuracy: 0.6645 - val_loss: 1.0058 - val_accuracy: 0.6326 - lr: 0.0010
# Epoch 33/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8868 - accuracy: 0.6687
# Epoch 33: val_loss did not improve from 0.97705
# 785/785 [==============================] - 49s 63ms/step - loss: 0.8868 - accuracy: 0.6687 - val_loss: 1.0072 - val_accuracy: 0.6240 - lr: 0.0010
# Epoch 34/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8785 - accuracy: 0.6722
# Epoch 34: val_loss did not improve from 0.97705
# 785/785 [==============================] - 51s 65ms/step - loss: 0.8785 - accuracy: 0.6722 - val_loss: 0.9877 - val_accuracy: 0.6342 - lr: 0.0010
# Epoch 35/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8826 - accuracy: 0.6680
# Epoch 35: val_loss did not improve from 0.97705
# 785/785 [==============================] - 51s 64ms/step - loss: 0.8826 - accuracy: 0.6680 - val_loss: 1.0192 - val_accuracy: 0.6298 - lr: 0.0010
# Epoch 36/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8650 - accuracy: 0.6740
# Epoch 36: val_loss did not improve from 0.97705
# 785/785 [==============================] - 51s 64ms/step - loss: 0.8650 - accuracy: 0.6740 - val_loss: 1.0176 - val_accuracy: 0.6329 - lr: 0.0010
# Epoch 37/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8579 - accuracy: 0.6776
# Epoch 37: val_loss did not improve from 0.97705
# 785/785 [==============================] - 50s 63ms/step - loss: 0.8579 - accuracy: 0.6776 - val_loss: 0.9786 - val_accuracy: 0.6354 - lr: 0.0010
# Epoch 38/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8556 - accuracy: 0.6793
# Epoch 38: val_loss did not improve from 0.97705
# 785/785 [==============================] - 51s 65ms/step - loss: 0.8556 - accuracy: 0.6793 - val_loss: 0.9981 - val_accuracy: 0.6447 - lr: 0.0010
# Epoch 39/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8459 - accuracy: 0.6814
# Epoch 39: val_loss did not improve from 0.97705
# 785/785 [==============================] - 51s 65ms/step - loss: 0.8459 - accuracy: 0.6814 - val_loss: 1.0169 - val_accuracy: 0.6404 - lr: 0.0010
# Epoch 40/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8387 - accuracy: 0.6892
# Epoch 40: val_loss did not improve from 0.97705
# 785/785 [==============================] - 50s 63ms/step - loss: 0.8387 - accuracy: 0.6892 - val_loss: 1.0234 - val_accuracy: 0.6373 - lr: 0.0010
# Epoch 41/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8260 - accuracy: 0.6912
# Epoch 41: val_loss did not improve from 0.97705
# 785/785 [==============================] - 50s 63ms/step - loss: 0.8260 - accuracy: 0.6912 - val_loss: 0.9898 - val_accuracy: 0.6376 - lr: 0.0010
# Epoch 42/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8270 - accuracy: 0.6928
# Epoch 42: val_loss did not improve from 0.97705
# 785/785 [==============================] - 50s 63ms/step - loss: 0.8270 - accuracy: 0.6928 - val_loss: 0.9869 - val_accuracy: 0.6385 - lr: 0.0010
# Epoch 43/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8228 - accuracy: 0.6928
# Epoch 43: val_loss did not improve from 0.97705
# 785/785 [==============================] - 50s 64ms/step - loss: 0.8228 - accuracy: 0.6928 - val_loss: 0.9883 - val_accuracy: 0.6373 - lr: 0.0010
# Epoch 44/50
# 785/785 [==============================] - ETA: 0s - loss: 0.7499 - accuracy: 0.7204
# Epoch 44: val_loss improved from 0.97705 to 0.93076, saving model to models/_Xception.44-0.67.hdf5
# 785/785 [==============================] - 52s 66ms/step - loss: 0.7499 - accuracy: 0.7204 - val_loss: 0.9308 - val_accuracy: 0.6657 - lr: 1.0000e-04
# Epoch 45/50
# 785/785 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.7328
# Epoch 45: val_loss did not improve from 0.93076
# 785/785 [==============================] - 50s 63ms/step - loss: 0.7198 - accuracy: 0.7328 - val_loss: 0.9362 - val_accuracy: 0.6660 - lr: 1.0000e-04
# Epoch 46/50
# 785/785 [==============================] - ETA: 0s - loss: 0.6990 - accuracy: 0.7376
# Epoch 46: val_loss did not improve from 0.93076
# 785/785 [==============================] - 51s 65ms/step - loss: 0.6990 - accuracy: 0.7376 - val_loss: 0.9373 - val_accuracy: 0.6691 - lr: 1.0000e-04
# Epoch 47/50
# 785/785 [==============================] - ETA: 0s - loss: 0.6878 - accuracy: 0.7432
# Epoch 47: val_loss did not improve from 0.93076
# 785/785 [==============================] - 51s 65ms/step - loss: 0.6878 - accuracy: 0.7432 - val_loss: 0.9377 - val_accuracy: 0.6701 - lr: 1.0000e-04
# Epoch 48/50
# 785/785 [==============================] - ETA: 0s - loss: 0.6857 - accuracy: 0.7454
# Epoch 48: val_loss improved from 0.93076 to 0.92828, saving model to models/_Xception.48-0.68.hdf5
# 785/785 [==============================] - 52s 66ms/step - loss: 0.6857 - accuracy: 0.7454 - val_loss: 0.9283 - val_accuracy: 0.6797 - lr: 1.0000e-04
# Epoch 49/50
# 785/785 [==============================] - ETA: 0s - loss: 0.6735 - accuracy: 0.7490
# Epoch 49: val_loss did not improve from 0.92828
# 785/785 [==============================] - 50s 63ms/step - loss: 0.6735 - accuracy: 0.7490 - val_loss: 0.9326 - val_accuracy: 0.6821 - lr: 1.0000e-04
# Epoch 50/50
# 785/785 [==============================] - ETA: 0s - loss: 0.6718 - accuracy: 0.7480
# Epoch 50: val_loss did not improve from 0.92828
# 785/785 [==============================] - 51s 64ms/step - loss: 0.6718 - accuracy: 0.7480 - val_loss: 0.9468 - val_accuracy: 0.6729 - lr: 1.0000e-04

# %% [markdown]
# It took around 45 to 50 minutes to run all 70 epochs. The training gave the accuracy of 72% approx and val_accuracy of 64%.
#
# It gives good prediction on train as well as test data.
#
# Let's see the performance of Trained Deep CNN model.

# %% [markdown]
# **Trained Deep Convolutional Neural Network(CNN):**

# %%
# Fitting the Model with Training and Validation Data
early_stop = EarlyStopping('val_loss', patience=50)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1,
                                  patience=25, min_lr=0.00001,model='auto')
trained_models_path = base_path + 'CNN'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,
                                                    save_best_only=True, mode='max')
callbacks = [model_checkpoint, early_stop, reduce_lr]

# %%
# Fitting the CNN model
CNN_history =CNN.fit(data_generator.flow(xtrain, ytrain, batch_size),
          steps_per_epoch=len(xtrain) / batch_size,
          epochs=num_epochs, 
          verbose=1, 
          callbacks=callbacks,
          validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 785/785 [==============================] - ETA: 0s - loss: 1.8588 - accuracy: 0.2669
# Epoch 1: val_loss improved from -inf to 1.75253, saving model to models/CNN.01-0.33.hdf5
# 785/785 [==============================] - 33s 38ms/step - loss: 1.8588 - accuracy: 0.2669 - val_loss: 1.7525 - val_accuracy: 0.3256 - lr: 0.0010
# Epoch 2/50
# 785/785 [==============================] - ETA: 0s - loss: 1.5518 - accuracy: 0.3984
# Epoch 2: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.5518 - accuracy: 0.3984 - val_loss: 1.4653 - val_accuracy: 0.4339 - lr: 0.0010
# Epoch 3/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.4066 - accuracy: 0.4582
# Epoch 3: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.4066 - accuracy: 0.4582 - val_loss: 1.3097 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 4/50
# 785/785 [==============================] - ETA: 0s - loss: 1.3221 - accuracy: 0.4936
# Epoch 4: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.3221 - accuracy: 0.4936 - val_loss: 1.2260 - val_accuracy: 0.5252 - lr: 0.0010
# Epoch 5/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.2773 - accuracy: 0.5110
# Epoch 5: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.2773 - accuracy: 0.5109 - val_loss: 1.2894 - val_accuracy: 0.5088 - lr: 0.0010
# Epoch 6/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.2464 - accuracy: 0.5263
# Epoch 6: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.2468 - accuracy: 0.5261 - val_loss: 1.1407 - val_accuracy: 0.5571 - lr: 0.0010
# Epoch 7/50
# 785/785 [==============================] - ETA: 0s - loss: 1.2195 - accuracy: 0.5386
# Epoch 7: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.2195 - accuracy: 0.5386 - val_loss: 1.1585 - val_accuracy: 0.5593 - lr: 0.0010
# Epoch 8/50
# 785/785 [==============================] - ETA: 0s - loss: 1.1962 - accuracy: 0.5456
# Epoch 8: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.1962 - accuracy: 0.5456 - val_loss: 1.1811 - val_accuracy: 0.5642 - lr: 0.0010
# Epoch 9/50
# 785/785 [==============================] - ETA: 0s - loss: 1.1716 - accuracy: 0.5558
# Epoch 9: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.1716 - accuracy: 0.5558 - val_loss: 1.1615 - val_accuracy: 0.5466 - lr: 0.0010
# Epoch 10/50
# 785/785 [==============================] - ETA: 0s - loss: 1.1577 - accuracy: 0.5650
# Epoch 10: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.1577 - accuracy: 0.5650 - val_loss: 1.0788 - val_accuracy: 0.5918 - lr: 0.0010
# Epoch 11/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.1396 - accuracy: 0.5740
# Epoch 11: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.1395 - accuracy: 0.5740 - val_loss: 1.0538 - val_accuracy: 0.5970 - lr: 0.0010
# Epoch 12/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.1163 - accuracy: 0.5798
# Epoch 12: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.1163 - accuracy: 0.5799 - val_loss: 1.0267 - val_accuracy: 0.6141 - lr: 0.0010
# Epoch 13/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.1163 - accuracy: 0.5754
# Epoch 13: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.1161 - accuracy: 0.5755 - val_loss: 1.0138 - val_accuracy: 0.6165 - lr: 0.0010
# Epoch 14/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0944 - accuracy: 0.5904
# Epoch 14: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0944 - accuracy: 0.5904 - val_loss: 1.0064 - val_accuracy: 0.6184 - lr: 0.0010
# Epoch 15/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0743 - accuracy: 0.5938
# Epoch 15: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0743 - accuracy: 0.5938 - val_loss: 1.0516 - val_accuracy: 0.5973 - lr: 0.0010
# Epoch 16/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.0669 - accuracy: 0.5978
# Epoch 16: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0671 - accuracy: 0.5978 - val_loss: 1.0186 - val_accuracy: 0.6196 - lr: 0.0010
# Epoch 17/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0522 - accuracy: 0.6053
# Epoch 17: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0522 - accuracy: 0.6053 - val_loss: 0.9996 - val_accuracy: 0.6178 - lr: 0.0010
# Epoch 18/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.0438 - accuracy: 0.6072
# Epoch 18: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0441 - accuracy: 0.6072 - val_loss: 1.0406 - val_accuracy: 0.6054 - lr: 0.0010
# Epoch 19/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0310 - accuracy: 0.6135
# Epoch 19: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0310 - accuracy: 0.6135 - val_loss: 0.9438 - val_accuracy: 0.6537 - lr: 0.0010
# Epoch 20/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.0238 - accuracy: 0.6158
# Epoch 20: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0237 - accuracy: 0.6159 - val_loss: 0.9467 - val_accuracy: 0.6425 - lr: 0.0010
# Epoch 21/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.0151 - accuracy: 0.6177
# Epoch 21: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0153 - accuracy: 0.6176 - val_loss: 0.9609 - val_accuracy: 0.6379 - lr: 0.0010
# Epoch 22/50
# 784/785 [============================>.] - ETA: 0s - loss: 1.0002 - accuracy: 0.6227
# Epoch 22: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0002 - accuracy: 0.6228 - val_loss: 0.9327 - val_accuracy: 0.6481 - lr: 0.0010
# Epoch 23/50
# 785/785 [==============================] - ETA: 0s - loss: 1.0010 - accuracy: 0.6249
# Epoch 23: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 1.0010 - accuracy: 0.6249 - val_loss: 0.9414 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 24/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9848 - accuracy: 0.6316
# Epoch 24: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9848 - accuracy: 0.6316 - val_loss: 0.9845 - val_accuracy: 0.6308 - lr: 0.0010
# Epoch 25/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9771 - accuracy: 0.6330
# Epoch 25: val_loss did not improve from 1.75253
# 785/785 [==============================] - 30s 38ms/step - loss: 0.9771 - accuracy: 0.6330 - val_loss: 0.9251 - val_accuracy: 0.6620 - lr: 0.0010
# Epoch 26/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.9723 - accuracy: 0.6358
# Epoch 26: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9723 - accuracy: 0.6357 - val_loss: 0.9832 - val_accuracy: 0.6305 - lr: 0.0010
# Epoch 27/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9638 - accuracy: 0.6359
# Epoch 27: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9638 - accuracy: 0.6359 - val_loss: 0.9040 - val_accuracy: 0.6555 - lr: 0.0010
# Epoch 28/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9537 - accuracy: 0.6391
# Epoch 28: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9537 - accuracy: 0.6391 - val_loss: 0.8985 - val_accuracy: 0.6589 - lr: 0.0010
# Epoch 29/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.9500 - accuracy: 0.6451
# Epoch 29: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9499 - accuracy: 0.6452 - val_loss: 0.9074 - val_accuracy: 0.6657 - lr: 0.0010
# Epoch 30/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9375 - accuracy: 0.6476
# Epoch 30: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9375 - accuracy: 0.6476 - val_loss: 0.8966 - val_accuracy: 0.6608 - lr: 0.0010
# Epoch 31/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9295 - accuracy: 0.6525
# Epoch 31: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9295 - accuracy: 0.6525 - val_loss: 0.8925 - val_accuracy: 0.6670 - lr: 0.0010
# Epoch 32/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9238 - accuracy: 0.6523
# Epoch 32: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 38ms/step - loss: 0.9238 - accuracy: 0.6523 - val_loss: 0.9043 - val_accuracy: 0.6546 - lr: 0.0010
# Epoch 33/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9126 - accuracy: 0.6586
# Epoch 33: val_loss did not improve from 1.75253
# 785/785 [==============================] - 30s 38ms/step - loss: 0.9126 - accuracy: 0.6586 - val_loss: 0.9262 - val_accuracy: 0.6546 - lr: 0.0010
# Epoch 34/50
# 785/785 [==============================] - ETA: 0s - loss: 0.9161 - accuracy: 0.6595
# Epoch 34: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9161 - accuracy: 0.6595 - val_loss: 0.9308 - val_accuracy: 0.6527 - lr: 0.0010
# Epoch 35/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.9112 - accuracy: 0.6581
# Epoch 35: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9111 - accuracy: 0.6581 - val_loss: 0.8847 - val_accuracy: 0.6679 - lr: 0.0010
# Epoch 36/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.9009 - accuracy: 0.6630
# Epoch 36: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.9011 - accuracy: 0.6629 - val_loss: 0.8920 - val_accuracy: 0.6710 - lr: 0.0010
# Epoch 37/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8980 - accuracy: 0.6656
# Epoch 37: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8980 - accuracy: 0.6656 - val_loss: 0.9055 - val_accuracy: 0.6685 - lr: 0.0010
# Epoch 38/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.8924 - accuracy: 0.6674
# Epoch 38: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8929 - accuracy: 0.6672 - val_loss: 0.9180 - val_accuracy: 0.6602 - lr: 0.0010
# Epoch 39/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8734 - accuracy: 0.6761
# Epoch 39: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8734 - accuracy: 0.6761 - val_loss: 0.8833 - val_accuracy: 0.6794 - lr: 0.0010
# Epoch 40/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.8710 - accuracy: 0.6744
# Epoch 40: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8710 - accuracy: 0.6744 - val_loss: 0.9143 - val_accuracy: 0.6623 - lr: 0.0010
# Epoch 41/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.8716 - accuracy: 0.6743
# Epoch 41: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8717 - accuracy: 0.6743 - val_loss: 0.9095 - val_accuracy: 0.6605 - lr: 0.0010
# Epoch 42/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8660 - accuracy: 0.6774
# Epoch 42: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8660 - accuracy: 0.6774 - val_loss: 0.8933 - val_accuracy: 0.6695 - lr: 0.0010
# Epoch 43/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.8555 - accuracy: 0.6838
# Epoch 43: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8557 - accuracy: 0.6838 - val_loss: 0.8995 - val_accuracy: 0.6685 - lr: 0.0010
# Epoch 44/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8581 - accuracy: 0.6785
# Epoch 44: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8581 - accuracy: 0.6785 - val_loss: 0.9120 - val_accuracy: 0.6602 - lr: 0.0010
# Epoch 45/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8520 - accuracy: 0.6815
# Epoch 45: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8520 - accuracy: 0.6815 - val_loss: 0.9540 - val_accuracy: 0.6543 - lr: 0.0010
# Epoch 46/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8483 - accuracy: 0.6841
# Epoch 46: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8483 - accuracy: 0.6841 - val_loss: 0.9015 - val_accuracy: 0.6719 - lr: 0.0010
# Epoch 47/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8412 - accuracy: 0.6876
# Epoch 47: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8412 - accuracy: 0.6876 - val_loss: 0.8827 - val_accuracy: 0.6735 - lr: 0.0010
# Epoch 48/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.8319 - accuracy: 0.6903
# Epoch 48: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8322 - accuracy: 0.6901 - val_loss: 0.8835 - val_accuracy: 0.6803 - lr: 0.0010
# Epoch 49/50
# 784/785 [============================>.] - ETA: 0s - loss: 0.8284 - accuracy: 0.6920
# Epoch 49: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8283 - accuracy: 0.6920 - val_loss: 0.8828 - val_accuracy: 0.6818 - lr: 0.0010
# Epoch 50/50
# 785/785 [==============================] - ETA: 0s - loss: 0.8181 - accuracy: 0.6906
# Epoch 50: val_loss did not improve from 1.75253
# 785/785 [==============================] - 29s 37ms/step - loss: 0.8181 - accuracy: 0.6906 - val_loss: 0.8983 - val_accuracy: 0.6821 - lr: 0.0010

# %% [markdown]
# It took around 30-35 minutes to run all epochs. The training gave the accuracy of 72% and va_accuracy of 69%. It seems quite good.

# %% [markdown]
# # **Plotting Accuracy & Loss**

# %%
# Plotting accuracy and loss curve for each model
fig,axes=plt.subplots(2,2,figsize=(20, 20))
for (m,history), ax in zip({'CNN':CNN_history,'Xception':xception_history}.items(),axes):
    # Loss Curves    
    ax[0].plot(history.history['loss'],'r',linewidth=2.0)
    ax[0].plot(history.history['val_loss'],'b',linewidth=2.0)
    ax[0].legend(['Training loss', 'Validation Loss'],fontsize=18)
    ax[0].set_xlabel('Epochs ',fontsize=16)
    ax[0].set_ylabel('Loss',fontsize=16)
    ax[0].set_title('Loss Curves '+m,fontsize=16)
 
    # Accuracy Curves
    ax[1].plot(history.history['accuracy'],'r',linewidth=2.0)
    ax[1].plot(history.history['val_accuracy'],'b',linewidth=2.0)
    ax[1].legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
    ax[1].set_xlabel('Epochs ',fontsize=16)
    ax[1].set_ylabel('Accuracy',fontsize=16)
    ax[1].set_title('Accuracy Curves '+m,fontsize=16)

# %%
# saving the plot
plt.savefig('plots.png')

# %% [markdown]
# From above loss and accuracy plot it is seen that the accuracy & loss curve of Trained Deep CNN model is gradually increasing also the validation loss curve is below the training loss curve on the other hand the Xception shows the slightly lower accuracy compare to the trained CNN model.

# %% [markdown]
# # **Classificastion Reports**

# %%
# Printing the classification report of all models
for model in [CNN,xception]:
    ypred=model.predict(xtest)
    ypred_=np.argmax(ypred, axis=1)
    ytest_=np.argmax(ytest, axis=1)
    print(classification_report(ytest_, ypred_,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.605     0.615     0.610       421
#            1      0.794     0.600     0.684        45
#            2      0.661     0.355     0.462       468
#            3      0.885     0.871     0.878       832
#            4      0.596     0.547     0.570       552
#            5      0.721     0.828     0.770       377
#            6      0.544     0.771     0.638       536
#
#     accuracy                          0.682      3231
#    macro avg      0.687     0.655     0.659      3231
# weighted avg      0.690     0.682     0.675      3231
#
#               precision    recall  f1-score   support
#
#            0      0.587     0.577     0.582       421
#            1      0.775     0.689     0.729        45
#            2      0.539     0.470     0.502       468
#            3      0.891     0.870     0.880       832
#            4      0.560     0.569     0.564       552
#            5      0.764     0.745     0.754       377
#            6      0.576     0.674     0.621       536
#
#     accuracy                          0.673      3231
#    macro avg      0.670     0.656     0.662      3231
# weighted avg      0.675     0.673     0.673      3231

# %% [markdown]
# From above classification report it is seen that the Recall, Precision and f1 score of Custom trained Deep CNN modedl is high compare to Xception model.

# %% [markdown]
# **Confusion Matrix**

# %%
import itertools
from sklearn.metrics import confusion_matrix
from matplotlib.pyplot import figure

# Printing the confusion matrix for each model
for model,i in zip([CNN,xception],[1,2,3]):
    fig = figure(figsize=(10, 10))
    
    ypred=model.predict(xtest)
    rounded_predections=np.argmax(ypred, axis=1)
    rounded_labels=np.argmax(ytest, axis=1)
    cm = confusion_matrix(rounded_labels, rounded_predections)
    labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
    title='Confusion matrix '+model.name
    

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig('confusion_matrix_'+model.name+'.png')
    plt.show()

# %% [markdown]
# From the confusion metrix above we observe the emotions that are correctly predicted w.r.t actual emotions.
#
# In above confusion metrices the Deep CNN model has predicted most of the emotions correctly comapare to Xception model.
#
# **Now we are going to use the Trained CNN Model for live video face emotion recognition.**

# %%
# Save best Model
CNN.save('Final_model.h5')

# %%
# Saving model in json format along with weights
fer_json = xception.to_json()  
with open("fer.json", "w") as json_file:  
    json_file.write(fer_json)  
xception.save_weights("fer.h5")

# %%
# import dependencies
from IPython.display import display, Javascript, Image,clear_output
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
# initialize the Haar Cascade face detection model
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %%
# Defining function to detect face
def face_detect():
  import cv2
  from PIL import Image
  import numpy as np
  import os
  from keras.models import load_model
  from time import sleep
  from keras.preprocessing.image import img_to_array
  from keras.preprocessing import image
# start streaming video from webcam
  video_stream()
# label for video
  label_html = 'Capturing...'
# initialze bounding box to empty
  bbox = ''
  count = 0
  face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + '/content/drive/MyDrive/face emotion recognition/files/my_env/haarcascade_frontalface_default.xml') # Face Detection
  classifier =load_model('/content/drive/MyDrive/face emotion recognition/files/my_env/Final_model.h5')  #Load model
  emotion_labels = ['Angry','Disgust','Fear','Happy','Neutral', 'Sad', 'Surprise'] 

  while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
      break

    # convert JS response to OpenCV Image
    img = js_to_image(js_reply["img"])

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)

    # grayscale image for face detection
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # get face region coordinates
    faces = face_cascade.detectMultiScale(gray)
    # get face bounding box for overlay
    for (x,y,w,h) in faces:
      bbox_array = cv2.rectangle(bbox_array,(x,y),(x+w,y+h),(0,255,0),2)
      roi_gray = gray[y:y+h,x:x+w]
      roi_gray = cv2.resize(roi_gray,(48,48),interpolation=cv2.INTER_AREA)  ##Face Cropping for prediction
      if np.sum([roi_gray])!=0:
        roi = roi_gray.astype('float')/255.0
        roi = img_to_array(roi)
        roi = np.expand_dims(roi,axis=0) ## reshaping the cropped face image for prediction
        prediction = classifier.predict(roi)[0]   #Prediction
        label=emotion_labels[prediction.argmax()]
        label_position = (x,y)
        cv2.putText(bbox_array,label,label_position,cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),2)   # Text Adding
      else:
        cv2.putText(bbox_array,'No Faces',(30,80),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),2)



    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes

# %%
# Finally detecting the face with live webcam
face_detect()

# %% [markdown]
# # **Conclusion:**
#
# The data preprocessing takes time for processing each image.
#
# The Custom trained CNN model gives training accuracy of 77% and test accuracy of 69% which is pretty good compare to the Xception model.
#
# Since, the emotion counts of disgust and fear images are less therefore on local webcam it hardly detect those emotions.
